# %%
# load the libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("AW01-HBS-COMBINED-2022-11-8-14-12-28-1667918027-v1.4.3+lucina-buzz.csv")
df.head()
# Out:
#     ts_r   acc_x_r   acc_y_r   acc_z_r  temp_r   gyr_x_r   gyr_y_r   gyr_z_r  \
# 0  64890  0.991943 -0.074951 -0.269287    3792 -1.220703 -1.800537  0.793457
# 1  64891  0.985352 -0.079346 -0.277588    3776 -1.129150 -0.579834  0.579834
# 2  64892  0.988770 -0.084229 -0.275391    3872 -0.701904  1.403809  1.037598
# 3  64893  0.990723 -0.081055 -0.264160    3760 -0.823975  1.098633  0.915527
# 4  64894  0.995605 -0.083984 -0.263672    3872  0.152588 -0.762939  1.037598
#
#    mag_x_r  mag_y_r  ...  in_bending_orange_zone  in_bending_red_zone  \
# 0      -15       52  ...                   False                False
# 1      -15       52  ...                   False                False
# 2     2986     3322  ...                   False                False
# 3     2986     3322  ...                   False                False
# 4     2982     3320  ...                   False                False
#
#    in_overreach_zone  bending_buzzing  overreach_buzzing  walking  vibrating  \
# 0              False            False              False    False      False
# 1              False            False              False    False      False
# 2              False            False              False    False      False
# 3              False            False              False    False      False
# 4              False            False              False    False      False
#
#    static_posture  label   label2
# 0               0  staan  normaal
# 1               0  staan  normaal
# 2               0  staan  normaal
# 3               0  staan  normaal
# 4               0  staan  normaal
#
# [5 rows x 42 columns]

# %%
df.keys()
# Out:
# Index(['ts_r', 'acc_x_r', 'acc_y_r', 'acc_z_r', 'temp_r', 'gyr_x_r', 'gyr_y_r',
#        'gyr_z_r', 'mag_x_r', 'mag_y_r', 'mag_z_r', 'kal_status_r', 'alpha_r',
#        'beta_r', 'ts_n', 'acc_x_n', 'acc_y_n', 'acc_z_n', 'temp_n', 'gyr_x_n',
#        'gyr_y_n', 'gyr_z_n', 'mag_x_n', 'mag_y_n', 'mag_z_n', 'kal_status_n',
#        'alpha_n', 'beta_n', 'started', 'calibrated', 'monitoring', 'zone',
#        'in_bending_orange_zone', 'in_bending_red_zone', 'in_overreach_zone',
#        'bending_buzzing', 'overreach_buzzing', 'walking', 'vibrating',
#        'static_posture', 'label', 'label2'],
#       dtype='object')

# %%
cols = df.columns
figure, ax1 = plt.subplots(figsize=(30, 8))
ax1.plot(df[cols[0]],df[cols[5]],linewidth=1.5,zorder=1,color='maroon')
ax1.plot(df[cols[0]],df[cols[7]],linewidth=2.5,zorder=1)

ax1.legend(['gyr_x_r','gyr_z_r'])

# %%
cols = df.columns
figure, ax1 = plt.subplots(figsize=(30, 8))
ax1.plot(df[cols[0]],df[cols[6]],linewidth=1.5,zorder=1,color='maroon')
ax1.plot(df[cols[0]],df[cols[7]],linewidth=2.5,zorder=1)

ax1.legend(['gyr_y_r','gyr_z_r'])

# %%
df1= df.drop(['alpha_n','beta_n','started','calibrated','vibrating'], axis=1)

corr = df1.corr() # Calculates correlation matrix

# plt.matshow(corr)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\khan\AppData\Local\Temp\ipykernel_6976\319996957.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr =
{
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_31bf3_row0_col32, #T_31bf3_row1_col5, #T_31bf3_row3_col5, #T_31bf3_row5_col3, #T_31bf3_row8_col16, #T_31bf3_row10_col5, #T_31bf3_row12_col27, #T_31bf3_row14_col32, #T_31bf3_row19_col30, #T_31bf3_row27_col15, #T_31bf3_row31_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_31bf3_row0_col33, #T_31bf3_row10_col18, #T_31bf3_row10_col21, #T_31bf3_row10_col29, #T_31bf3_row14_col33, #T_31bf3_row15_col27, #T_31bf3_row28_col15, #T_31bf3_row29_col0, #T_31bf3_row29_col14 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_31bf3_row0_col34, #T_31bf3_row4_col16, #T_31bf3_row14_col34, #T_31bf3_row16_col34, #T_31bf3_row21_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_31bf3_row1_col0, #T_31bf3_row1_col14, #T_31bf3_row7_col30, #T_31bf3_row10_col6, #T_31bf3_row22_col28, #T_31bf3_row23_col11, #T_31bf3_row26_col30, #T_31bf3_row32_col22 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_31bf3_row1_col2, #T_31bf3_row2_col1, #T_31bf3_row2_col15, #T_31bf3_row15_col2 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_31bf3_row1_col3, #T_31bf3_row4_col29, #T_31bf3_row4_col31, #T_31bf3_row5_col31, #T_31bf3_row11_col22, #T_31bf3_row12_col34, #T_31bf3_row13_col7, #T_31bf3_row31_col27 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_31bf3_row1_col4, #T_31bf3_row7_col4, #T_31bf3_row7_col33, #T_31bf3_ro

# %%
cols = df.columns
figure, ax1 = plt.subplots(figsize=(20, 4))
ax1.plot(df[cols[0]],df[cols[1]],linewidth=1.5,zorder=1,color='maroon')
ax1.plot(df[cols[0]],df[cols[15]],linewidth=1.5,zorder=1)
# ax1.plot(df[cols[0]],df[cols[6]],linewidth=0.5,zorder=1, label = "Force2")
ax1.legend(['acc_x_r', 'acc_x_n'])

# %%
cols = df.columns
figure, ax1 = plt.subplots(figsize=(20, 4))
ax1.plot(df[cols[0]],df[cols[1]],linewidth=1.5,zorder=1,color='maroon')
ax1.plot(df[cols[0]],df[cols[35]],linewidth=1.5,zorder=1)
# ax1.plot(df[cols[0]],df[cols[6]],linewidth=0.5,zorder=1, label = "Force2")
ax1.legend(['acc_x_r','bending_buzzing'])

# %%
cols = df.columns
figure, ax1 = plt.subplots(figsize=(20, 4))
ax1.plot(df[cols[0]],df[cols[1]],linewidth=1.5,zorder=1,color='maroon')
ax1.plot(df[cols[0]],df[cols[33]],linewidth=1.5,zorder=1)
# ax1.plot(df[cols[0]],df[cols[6]],linewidth=0.5,zorder=1, label = "Force2")
ax1.legend(['acc_x_r','in_bending_red_zone'])

# %%
cols = df.columns
figure, ax1 = plt.subplots(figsize=(30, 8))
ax1.plot(df[cols[0]],df[cols[22]],linewidth=1.5,zorder=1,color='maroon')
ax1.plot(df[cols[0]],df[cols[23]],linewidth=2.5,zorder=1)
ax1.plot(df[cols[0]],df[cols[24]],linewidth=2.5,zorder=1)

ax1.legend(['mag_x_n','mag_y_n','mag_z_n'])

# %%
cols = df.columns
figure, ax1 = plt.subplots(figsize=(30, 8))
ax1.plot(df[cols[0]],df[cols[8]],linewidth=1.5,zorder=1,color='maroon')
ax1.plot(df[cols[0]],df[cols[9]],linewidth=2.5,zorder=1)
ax1.plot(df[cols[0]],df[cols[10]],linewidth=2.5,zorder=1)

ax1.legend(['mag_x_r','mag_y_r','mag_z_r'])
